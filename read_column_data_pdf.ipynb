# %%
import re
import json
import PyPDF2

column_names = []
column_indices = []

PAGE_START = 21
PAGE_END = 150

PDF_PATH = './data/2015/cpsjul15.pdf'
JSON_PATH = './data/2015/cspjul15variables.json'

with open(JSON_PATH, 'r') as file:
    # read the json file - create a dictionary of the data
    variable_names = json.load(file)['variables'].keys()

# Remove some extra variables
variables = list(set(variable_names) - {"for", "in", "ucgid"})
print("The variables are:  ", variables)

# Open the PDF file
with open(PDF_PATH, 'rb') as file:
    # Read the PDF file
    pdf_reader = PyPDF2.PdfReader(file)

    for page_number in range(PAGE_START, PAGE_END):
        # get the page number
        page = pdf_reader.pages[page_number]

        # Extract the text from the page
        page_text = page.extract_text()

        # Print the contents of the page
        # print(page_text)

        # Regex to check if the line ends with a number
        regex = re.compile(r'\d{1,4}[ ]?-[ ]?\d{1,4}$')

        for line in page_text.split('\n'):
            line = line.strip()
            
            if len(line) == 0:
                continue

            # If the line contains one of the variable names
            num_variables_in_line = 0
            col_name = None
            col_index = None

            for variable in variables:
                # why space? because some variables are substrings of other variables
                if variable+' ' in line and regex.search(line):

                    # if the line contains the variable name followed by an equal sign, it is just a description.
                    if re.search(rf'{variable}[\s]*=', line):
                        continue

                    num_variables_in_line += 1
                    matching_string = regex.findall(line)[-1]

                    col_name = variable
                    col_index = matching_string
                
            if num_variables_in_line > 1:  print("More than one variable in line: " + line + " " + str([variable for variable in variables if variable+' ' in line]))
            elif col_name is not None:
                    column_names.append(col_name)
                    column_indices.append([x.strip() for x in col_index.split('-')])
# Out:
# The variables are:   ['HUBUSL4', 'PEDISDRS', 'HEFAMINC', 'PTIO2OCD', 'PRDTHSP', 'HEBUNSV2', 'HETENURE', 'PTDTRACE', 'PEAFWHN1', 'PXABSRSN', 'PTERNWA', 'PULAYCK1', 'PRFAMTYP', 'PRINUYER', 'PULKDK6', 'PXIO1OCD', 'PTERNH1C', 'HEOUTMOB', 'GTCBSAST', 'PXDWAVR', 'PRDTCOW2', 'HEPSCON6', 'PXERNH2', 'PXMJNUM', 'PRHRUSL', 'PESPOUSE', 'PRPTHRS', 'PRIOELG', 'PELAYLK', 'HEBUNDLE', 'PULAY', 'HENOOU7', 'PEVIDEO', 'PXLKLL1O', 'PEECOMME', 'PTHR', 'PXLAYLK', 'HENOOU2', 'PREMPHRS', 'PXDWLKO', 'HECYBA', 'PERRP', 'PEHRWANT', 'HENOHM3', 'PEIO2COW', 'PULKDK5', 'PELNMOM', 'PRMJOCC2', 'PEMARITL', 'HUBUSL1', 'GTCSA', 'PECOHAB', 'PTERNH2', 'PETVBOX', 'PEEDUCA', 'HEEVRHOM', 'HENOOU10', 'PXIO1COW', 'PXDISDRS', 'HELAPTOP', 'PEEDTRAI', 'HEPRINOH', 'PUBUSCK2', 'HEPSCON4', 'PESEX', 'PUJHCK5', 'HENOHM2', 'PUHRCK12', 'PUHRCK7', 'HENOOU3', 'HEOUTCK', 'PUBUS1', 'PXLKM1', 'HXTELAVL', 'PULKM4', 'PEHRACT2', 'HEBUNSV1', 'PUDWCK3', 'PRCIVLF', 'PUHROT1', 'PWPRMWGT', 'PUSLFPRX', 'PRWKSTAT', 'PXDISPHY', 'PEDWAVL', 'PELAPTOP', 'PULKDK2', 'HENOHM6', 'HEBUNSV5', 'PEDISEYE', 'HEPSCON7', 'HEHOMTE4', 'PXSPOUSE', 'PTNMEMP1', 'PULKAVR', 'HEWEARAB', 'PULAY6M', 'PELAYAVL', 'PRFTLF', 'PXERNRT', 'PEDIPGED', 'HRINTSTA', 'HENOHM9', 'PXRACE1', 'HENOOU5', 'HEBUNSV3', 'PEPARENT', 'PEERNUOT', 'PRDTCOW1', 'PULAYCK2', 'PXERN', 'PULKPS4', 'PEERNHRO', 'PEINTRAV', 'PRPERTYP', 'PXHRFTPT', 'PUHRCK6', 'PUWK', 'PRPTREA', 'PXERNLAB', 'PXIO1ICD', 'HUTYPEA', 'PXIO2ICD', 'HEINOTHR', 'HEPSCON2', 'PUJHCK4', 'PUHRCK2', 'PRMJOCGR', 'PEONTHEG', 'PXRET1', 'PESCHENR', 'PUNLFCK2', 'HEINHOME', 'PXDISREM', 'PURETOT', 'PXHRRSN2', 'HEHOMTE5', 'PRDASIAN', 'PXMLR', 'PRERELG', 'HEHOMTE2', 'PXDISEYE', 'PETEXTIM', 'HETVBOX', 'HEPSPRE2', 'PRFAMREL', 'HURESPLI', 'PXLKAVL', 'PXPDEMP1', 'PRCITFLG', 'HXTENURE', 'PEERNLAB', 'PRJOBSEA', 'HEHOMSU1', 'PEMNTVTY', 'PEJOBSCH', 'PXLAYAVL', 'HEHOMSU5', 'PEDISREM', 'PUIOCK2', 'HEPRINOO', 'PEFINANC', 'HEPSCON1', 'PXLKDUR', 'PXLKFTO', 'PEAFWHN2', 'PRCITSHP', 'PXHRWANT', 'PRDISC', 'PEAFEVER', 'PREMPNOT', 'PULKDK3', 'GTCBSASZ', 'PETELEWK', 'PRCHLD', 'PEHRUSLT', 'PEINELHO', 'HEHOMTE1', 'PXSCHFT', 'PTERNHLY', 'PXMARITL', 'PUDWCK1', 'PEDWWNTO', 'PXAFWHN1', 'PUIODP2', 'PEHRACTT', 'PXHRACT2', 'HRLONGLK', 'PEDWLKO', 'PUNLFCK1', 'PXNLFACT', 'PWFMWGT', 'PEHRUSL1', 'PUBUS2OT', 'PRFAMNUM', 'PESOCIAL', 'PECONFER', 'PUIO2MFG', 'PUELGFLG', 'PXAFNOW', 'PEDWLKWK', 'PELKLL2O', 'PELKLWO', 'PEHRACT1', 'PXABSPDO', 'HENOHM10', 'PWVETWGT', 'PXPARENT', 'HEDESKTP', 'PEINCAFE', 'PRUNEDUR', 'HEPHONEO', 'PEMOMTYP', 'PXHRUSL2', 'PXERNUOT', 'PEEMAIL', 'HENOOU6', 'PEERNCOV', 'HEHOUSUT', 'PXERNHRY', 'HEHOMSU2', 'PXDWRSN', 'PUABSOT', 'PEIO1ICD', 'HENOHM7', 'PRDTOCC1', 'PXNMEMP1', 'HEHOMSU4', 'PUHRCK3', 'PEPDEMP1', 'HENOOU9', 'PEIO1COW', 'PXDWWNTO', 'PULKPS1', 'PUHRCK1', 'PXDIPGED', 'GESTFIPS', 'PRMJOCC1', 'PXMJOT', 'PULK', 'PEDISPHY', 'HETELAVL', 'PRWERNAL', 'PULKPS3', 'PEABSPDO', 'PWSSWGT', 'PEDWRSN', 'PELNDAD', 'PXHRACT1', 'PRNAGPWS', 'PEMLR', 'HRHHID2', 'PEERNWKP', 'PXLKLWO', 'HEINLICO', 'PXERNPER', 'PEHRUSL2', 'PUJHCK2', 'HENOOU4', 'HXPHONEO', 'PXJHWKO', 'HWHHWTLN', 'PULINENO', 'PRCOW2', 'HUINTTYP', 'PETABLET', 'PEDESKTP', 'PEJHWKO', 'PEIO2ICD', 'PUIODP1', 'PULKPS5', 'PRNAGWS', 'PENLFJH', 'HEPSCON5', 'HUBUS', 'HEPSENSI', 'PRTFAGE', 'HEEVROUT', 'PXNATVTY', 'HENOOU1', 'HENOHM5', 'PRWNTJOB', 'HENOHM1', 'PWLGWGT', 'HEMPHONE', 'PEMEDMON', 'PXERNWKP', 'PXIO2OCD', 'HXFAMINC', 'PXNLFJH', 'HEHOMFAC', 'HEPSPRE1', 'PXHGCOMP', 'HEHOMSU3', 'PXAGE', 'PEMJOT', 'PELAYDUR', 'PEWEBBRO', 'HETABLET', 'PULKM5', 'PELKLL1O', 'PENLFRET', 'PEAFWHN4', 'PXERNH1O', 'PXIO2COW', 'PELKDUR', 'PRSJMJ', 'PXHRUSLT', 'PEMJNUM', 'PEAFNOW', 'PRTAGE', 'PUDIS', 'PULKDK4', 'PEPDEMP2', 'PELKM1', 'PXLAYFTO', 'PXSEX', 'PXCYC', 'HUFINAL', 'PUBUSCK4', 'PUJHCK3', 'PTWK', 'PULKPS6', 'PRCOWPG', 'PELKFTO', 'HEINELHO', 'HUTYPB', 'PUBUSCK3', 'PUIOCK1', 'PEDADTYP', 'PUIODP3', 'HEHOMTE3', 'PXHRAVL', 'PRMARSTA', 'PRDTOCC2', 'PXINUSYR', 'PULAYDT', 'PRUNTYPE', 'PUDWCK2', 'PESCHFT', 'HRHTYPE', 'PEHRRSN1', 'PEMEDINF', 'PEAUDIO', 'PREXPLF', 'HENOHM8', 'PEJHRSN', 'HETELHHD ...
# More than one variable in line: 1 3  O T H E R  P A S S I V E   PULKM5  2   SAME AS PULKM2 (FIFTH METHOD)     304 - 305 ['PULKM5', 'PULKM2']
# More than one variable in line: 11 ATTENDED JOB TRAINING PROGRAMS/COURSES       1 3  O T H E R  P A S S I V E   PULKM6  2   SAME AS PULKM2 (SIXTH METHOD)     306 - 307 ['PULKM6', 'PULKM2']
# More than one variable in line: 1 3  O T H E R  P A S S I V E   PULKDK3  2  SAME AS PULKDK2 (THIRD METHOD)    312 - 313 ['PULKDK2', 'PULKDK3']
# More than one variable in line: 1 3  O T H E R  P A S S I V E   PULKDK4  2  SAME AS PULKDK2 (FOURTH METHOD)    314 - 315 ['PULKDK2', 'PULKDK4']
# More than one variable in line: 11 ATTENDED JOB TRAINING PROGRAMS/COURSES       1 3  O T H E R  P A S S I V E   PULKDK5  2  SAME AS PULKDK2 (FIFTH METHOD)    316 - 317 ['PULKDK5', 'PULKDK2']
# More than one variable in line: 11 ATTENDED JOB TRAINING PROGRAMS/COURSES       1 3  O T H E R  P A S S I V E   PULKPS3  2   SAME AS PULKPS2 (THIRD METHOD)    324 - 325 ['PULKPS3', 'PULKPS2']
# More than one variable in line: 10 LOOKED AT ADS       11 ATTENDED JOB TRAINING PROGRAMS/COURSES       1 3  O T H E R  P A S S I V E   PULKPS4  2   SAME AS PULKPS2 (FOURTH METHOD)    326 - 327 ['PULKPS4', 'PULKPS2']
# More than one variable in line: PULKPS5  2   SAME AS PULKPS2 (FIFTH METHOD)     328 - 329 ['PULKPS5', 'PULKPS2']
# More than one variable in line: 3 IF ENTRY OF 5 IN DWWNT GOTO PUDIS2       4 ALL OTHERS GOTO PUDWCK4  PUDWCK3  2  FILTER FOR RETIRED        367 - 368 ['PUDWCK3', 'PUDIS2', 'PUDWCK4']
# More than one variable in line: See HETENURE note.  HXHOUSUT  2  ALLOCATION FLAG        645 - 646 ['HETENURE', 'HXHOUSUT']
# More than one variable in line: HXTELAVL  2  ALLOCATION FLAG        649 - 650  HXPHONEO  2  ALLOCATION FLAG        651 - 652 ['HXTELAVL', 'HXPHONEO']
# More than one variable in line: PXRRP   2  ALLOCATION FLAG        655 - 656   PXPARENT  2  ALLOCATION FLAG        657 - 658 ['PXPARENT', 'PXRRP']
# More than one variable in line: PXSPOUSE  2  ALLOCATION FLAG        663 - 664  PXSEX   2  ALLOCATION FLAG        665 - 666 ['PXSPOUSE', 'PXSEX']
# More than one variable in line: PXAFNOW  2  ALLOCATION FLAG        669 - 670  PXEDUCA   2  ALLOCATION FLAG        671 - 672 ['PXAFNOW', 'PXEDUCA']
# More than one variable in line: PXNATVTY  2  ALLOCATION FLAG        675 - 676  PXMNTVTY  2  ALLOCATION FLAG        677 - 678 ['PXNATVTY', 'PXMNTVTY']
# More than one variable in line: PXFNTVTY  2  ALLOCATION FLAG        679 - 680  PXNMEMP1  2  ALLOCATION FLAG        681 - 682  PXHSPNON  2  ALLOCATION FLAG        683 - 684 ['PXNMEMP1', 'PXFNTVTY', 'PXHSPNON']
# More than one variable in line: PXMLR   2  ALLOCATION FLAG        685 - 686   PXRET1   2  ALLOCATION FLAG        687 - 688 ['PXRET1', 'PXMLR']
# More than one variable in line: PXABSPDO  2  ALLOCATION FLAG        691 - 692   PXMJOT   2  ALLOCATION FLAG        693 - 694 ['PXABSPDO', 'PXMJOT']
# More than one variable in line: PXMJNUM  2  ALLOCATION FLAG        695 - 696   PXHRUSL1  2  ALLOCATION FLAG        697 - 698   PXHRUSL2  2  ALLOCATION FLAG        699 - 700 ['PXMJNUM', 'PXHRUSL2', 'PXHRUSL1']
# More than one variable in line: PXHRFTPT  2  ALLOCATION FLAG        701 - 702   PXHRUSLT  2  ALLOCATION FLAG        703 - 704 ['PXHRFTPT', 'PXHRUSLT']
# More than one variable in line: PXHRRSN2  2  ALLOCATION FLAG        709 – 710   PXHRACT1  2  ALLOCATION FLAG        711 - 712 ['PXHRRSN2', 'PXHRACT1']
# More than one variable in line: PXHRACTT  2  ALLOCATION FLAG        715 - 716   PXHRRSN3  2  ALLOCATION FLAG        717 - 718 ['PXHRRSN3', 'PXHRACTT']
# More than one variable in line: PXLAYAVL  2  ALLOCATION FLAG        721 - 722   PXLAYLK   2  ALLOCATION FLAG        723 - 724 ['PXLAYLK', 'PXLAYAVL']
# More than one variable in line: PXLAYDUR  2  ALLOCATION FLAG        725 - 726  PXLAYFTO  2  ALLOCATION FLAG        727 - 728   PXLKM1   2  ALLOCATION FLAG        729 - 730 ['PXLKM1', 'PXLAYFTO', 'PXLAYDUR']
# More than one variable in line: PXLKAVL   2  ALLOCATION FLAG        731 - 732   PXLKLL1O  2  ALLOCATION FLAG        733 - 734 ['PXLKLL1O', 'PXLKAVL']
# More than one variable in line: PXLKLWO  2  ALLOCATION FLAG        737 - 738  PXLKDUR   2  ALLOCATION FLAG        739 - 740 ['PXLKDUR', 'PXLKLWO']
# More than one variable in line: PXLKFTO   2  ALLOCATION FLAG        741 - 742   PXDWWNTO  2  ALLOCATION FLAG        743 - 744   PXDWRSN  2  ALLOCATION FLAG        745 - 746 ['PXLKFTO', 'PXDWRSN', 'PXDWWNTO']
# More than one variable in line: PXDWLKO  2  ALLOCATION FLAG        747 - 748   PXDWWK   2  ALLOCATION FLAG        749 - 750 ['PXDWLKO', 'PXDWWK']
# More than one variable in line: PXDWAVL  2  ALLOCATION FLAG        755 - 756   PXDWAVR  2  ALLOCATION FLAG        757 - 758 ['PXDWAVR', 'PXDWAVL']
# More than one variable in line: PXJHRSN   2  ALLOCATION FLAG        761 - 762   PXJHWANT  2  ALLOCATION FLAG        763 - 764 ['PXJHWANT', 'PXJHRSN']
# More than one variable in line: PXIO1ICD   2  ALLOCATION FLAG        767 - 768   PXIO1OCD  2       ALLOCATION FLAG        769 - 770 ['PXIO1OCD', 'PXIO1ICD']
# More than one variable in line: PXIO2COW  2  ALLOCATION FLAG        771 - 772   PXIO2ICD   2  ALLOCATION FLAG        773 - 774   PXIO2OCD  2  ALLOCATION FLAG        775 - 776 ['PXIO2ICD', 'PXIO2OCD', 'PXIO2COW']
# More than one variable in line: PXERNUOT  2  ALLOCATION FLAG        777 - 778   PXERNPER  2  ALLOCATION FLAG        779 - 780 ['PXERNUOT', 'PXERNPER']
# More than one variable in line: PXERNHRO  2  ALLOCATION FLAG        783 - 784   PXERN   2  ALLOCATION FLAG        785 - 786 ['PXERN', 'PXERNHRO']
# More than one variable in line: PXPDEMP2  2  ALLOCATION FLAG        787 - 788  PXNMEMP2  2  ALLOCATION FLAG        789 - 790  PXERNWKP  2  ALLOCATION FLAG        791 - 792 ['PXERNWKP', 'PXNMEMP2', 'PXPDEMP2']
# More than one variable in line: PXERNCOV  2  ALLOCATION FLAG        801 - 802  PXNLFJH   2  ALLOCATION FLAG        803 - 804 ['PXNLFJH', 'PXERNCOV']
# More than one variable in line: PXNLFACT  2  ALLOCATION FLAG        807 - 808  PXSCHENR  2  ALLOCATION FLAG        809 - 810 ['PXNLFACT', 'PXSCHENR']
# More than one variable in line: PXHGCOMP  2   ALLOCATION FLAG        836 - 837  PXCYC   2  ALLOCATION FLAG        838 - 839  PADDING   6              840 - 845 ['PXHGCOMP', 'PXCYC']
# More than one variable in line: PXAFEVER  2  ALLOCATION FLAG        884 - 885  PELNDAD   2  LINE NUMBER OF FATHER       886 - 887 ['PELNDAD', 'PXAFEVER']
# More than one variable in line: -1 NO MOTHER PRESENT        01 MIN VALUE        16 MAX VALUE  PEDADTYP  2  TYPE OF FATHER        890 – 891         EDITED UNVERSE:   ALL         -1 NO FATHER PRESENT        01 BIOLOGICAL         02 STEP        03 ADOPTED  PEMOMTYP  2  TYPE OF MO THER        892 - 893 ['PEMOMTYP', 'PEDADTYP']

# %%
column_index_mapping = dict(zip(column_names, column_indices))
column_index_mapping
# Out:
# {'HEHOUSUT': ['31', '32'],
#  'HETELHHD': ['33', '34'],
#  'HETELAVL': ['35', '36'],
#  'HEPHONEO': ['37', '38'],
#  'HUTYPEA': ['41', '42'],
#  'HUTYPB': ['43', '44'],
#  'HUTYPC': ['45', '46'],
#  'HWHHWGT': ['47', '56'],
#  'HRINTSTA': ['57', '58'],
#  'HRHTYPE': ['61', '62'],
#  'HRMIS': ['63', '64'],
#  'HUPRSCNT': ['67', '68'],
#  'HRLONGLK': ['69', '70'],
#  'HRHHID2': ['71', '75'],
#  'HUBUS': ['79', '80'],
#  'HUBUSL2': ['83', '84'],
#  'HUBUSL3': ['85', '86'],
#  'HUBUSL4': ['87', '88'],
#  'GESTFIPS': ['93', '94'],
#  'GTCO': ['101', '103'],
#  'GTCBSAST': ['104', '104'],
#  'GTMETSTA': ['105', '105'],
#  'GTINDVPC': ['106', '106'],
#  'GTCBSASZ': ['107', '107'],
#  'PERRP': ['118', '119'],
#  'PEPARENT': ['120', '121'],
#  'PRTAGE': ['122', '123'],
#  'PRTFAGE': ['124', '124'],
#  'PEMARITL': ['125', '126'],
#  'PESPOUSE': ['127', '128'],
#  'PEAFEVER': ['131', '132'],
#  'PEAFNOW': ['135', '136'],
#  'PRDTHSP': ['141', '142'],
#  'PRFAMREL': ['153', '154'],
#  'PRFAMTYP': ['155', '156'],
#  'PEHSPNON': ['157', '158'],
#  'PEFNTVTY': ['169', '171'],
#  'PRCITFLG': ['174', '175'],
#  'PUSLFPRX': ['178', '179'],
#  'PEMLR': ['180', '181'],
#  'PUBUS1': ['184', '185'],
#  'PUBUSCK1': ['188', '189'],
#  'PUBUSCK3': ['192', '193'],
#  'PERET1': ['200', '201'],
#  'PUDIS1': ['202', '203'],
#  'PUDIS2': ['204', '205'],
#  'PULAY': ['208', '209'],
#  'PEABSPDO': ['212', '213'],
#  'PEHRFTPT': ['222', '223'],
#  'PEHRUSLT': ['224', '226'],
#  'PEHRWANT': ['227', '228'],
#  'PEHRRSN1': ['229', '230'],
#  'PEHRRSN2': ['231', '232'],
#  'PEHRACT1': ['243', '244'],
#  'PEHRAVL': ['250', '251'],
#  'PUHRCK2': ['259', '260'],
#  'PUHRCK4': ['263', '264'],
#  'PUHRCK7': ['269', '270'],
#  'PULAYDT': ['273', '274'],
#  'PULAY6M': ['275', '276'],
#  'PELAYAVL': ['277', '278'],
#  'PULAYAVR': ['279', '280'],
#  'PELAYDUR': ['410', '411'],
#  'PULAYCK2': ['290', '291'],
#  'PULAYCK3': ['292', '293'],
#  'PULKM2': ['298', '299'],
#  'PULKDK1': ['308', '309'],
#  'PULKDK2': ['310', '311'],
#  'PULKPS2': ['322', '323'],
#  'PULKAVR': ['334', '335'],
#  'PELKLL2O': ['338', '339'],
#  'PELKLWO': ['340', '341'],
#  'PELKDUR': ['342', '344'],
#  'PELKFTO': ['345', '346'],
#  'PEDWRSN': ['349', '350'],
#  'PEDW4WK': ['355', '356'],
#  'PEDWLKWK': ['357', '358'],
#  'PEDWAVL': ['359', '360'],
#  'PUDWCK2': ['365', '366'],
#  'PUDWCK4': ['369', '370'],
#  'PUDWCK5': ['371', '372'],
#  'PUJHDP1O': ['375', '376'],
#  'PUJHCK1': ['381', '382'],
#  'PUJHCK2': ['383', '384'],
#  'PRABSREA': ['385', '386'],
#  'PRCIVLF': ['387', '388'],
#  'PRDISC': ['389', '390'],
#  'PREMPHRS': ['391', '392'],
#  'PREMPNOT': ['1', '7'],
#  'PRFTLF': ['1', '4'],
#  'PRHRUSL': ['399', '400'],
#  'PRPTHRS': ['403', '404'],
#  'PRUNEDUR': ['407', '409'],
#  'PRUNTYPE': ['412', '413'],
#  'PRWKSCH': ['1', '7'],
#  'PRWKSTAT': ['416', '417'],
#  'PRWNTJOB': ['418', '419'],
#  'PUJHCK4': ['422', '423'],
#  'PUJHCK5': ['424', '425'],
#  'PEIO2COW': ['442', '443'],
#  'PUIO2MFG': ['444', '445'],
#  'PRIOELG': ['458', '459'],
#  'PRAGNA': ['460', '461'],
#  'PRCOW2': ['464', '465'],
#  'PRCOWPG': ['466', '467'],
#  'PRDTCOW2': ['470', '471'],
#  'PRDTIND2': ['474', '475'],
#  'PRDTOCC2': ['478', '479'],
#  'PREMP': ['480', '481'],
#  'PRMJIND1': ['482', '483'],
#  'PRMJIND2': ['484', '485'],
#  'PRMJOCC1': ['1', '46'],
#  'PRMJOCC2': ['488', '489'],
#  'PRMJOCGR': ['1', '11'],
#  'PRNAGWS': ['1', '4'],
#  'PEIO1ICD': ['856', '859'],
#  'PRSJMJ': ['496', '497'],
#  'PRERELG': ['498', '499'],
#  'PEERNPER': ['502', '503'],
#  'PEERNRT': ['504', '505'],
#  'PEERNHRY': ['506', '507'],
#  'PEERNHRO': ['525', '526'],
#  'PEERNWKP': ['559', '560'],
#  'PENLFRET': ['567', '568'],
#  'PESCHENR': ['575', '576'],
#  'PRNLFSCH': ['581', '582'],
#  'PWLGWGT': ['593', '602'],
#  'PWORWGT': ['603', '612'],
#  'PRCHLD': ['633', '634'],
#  'PXPDEMP1': ['637', '638'],
#  'PRWERNAL': ['639', '640'],
#  'PRHERNAL': ['641', '642'],
#  'HXTENURE': ['643', '644'],
#  'HXTELHHD': ['647', '648'],
#  'PXINUSYR': ['653', '654'],
#  'PXAGE': ['659', '660'],
#  'PXMARITL': ['661', '662'],
#  'PXAFWHN1': ['667', '668'],
#  'PXRACE1': ['673', '674'],
#  'PXABSRSN': ['689', '690'],
#  'PXHRWANT': ['705', '706'],
#  'PXHRRSN1': ['707', '708'],
#  'PXHRACT2': ['713', '714'],
#  'PXHRAVL': ['719', '720'],
#  'PXLKLL2O': ['735', '736'],
#  'PXDW4WK': ['751', '752'],
#  'PXDWLKWK': ['753', '754'],
#  'PXJHWKO': ['759', '760'],
#  'PXIO1COW': ['765', '766'],
#  'PXERNH1O': ['781', '782'],
#  'PXERNH2': ['797', '798'],
#  'PXERNLAB': ['799', '800'],
#  'PXNLFRET': ['805', '806'],
#  'PXSCHFT': ['811', '812'],
#  'PXSCHLVL': ['815', '819'],
#  'PEDIPGED': ['822', '823'],
#  'PECYC': ['40', '42'],
#  'PXDIPGED': ['834', '835'],
#  'PEIO2ICD': ['864', '867'],
#  'PEAFWHN1': ['876', '877'],
#  'PEAFWHN2': ['878', '879'],
#  'PELNMOM': ['888', '889'],
#  'PECOHAB': ['894', '895'],
#  'PEDISEAR': ['906', '907'],
#  'PEDISEYE': ['908', '909'],
#  'PEDISREM': ['910', '911'],
#  'PEDISOUT': ['916', '917'],
#  'PRDISFLG': ['918', '919'],
#  'PXDISEAR': ['920', '921'],
#  'PXDISEYE': ['922', '923'],
#  'PXDISREM': ['924', '925'],
#  'PXDISPHY': ['926', '927'],
#  'PXDISDRS': ['928', '929'],
#  'PXDISOUT': ['930', '931'],
#  'HXFAMINC': ['932', '933'],
#  'PEPDEMP1': ['936', '937'],
#  'PEPDEMP2': ['940', '941'],
#  'PTNMEMP2': ['942', '943'],
#  'HEDESKTP': ['951', '952'],
#  'PEDESKTP': ['953', '954'],
#  'HELAPTOP': ['955', '956'],
#  'PELAPTOP': ['957', '958'],
#  'HETABLET': ['959', '960'],
#  'PETABLET': ['961', '962'],
#  'HEMPHONE': ['963', '964'],
#  'PEMPHONE': ['965', '966'],
#  'HEWEARAB': ['967', '968'],
#  'PEWEARAB': ['969', '970'],
#  'HETVBOX': ['971', '972'],
#  'PETVBOX': ['973', '974'],
#  'HEINHOME': ['975', '976'],
#  'PEINHOME': ['977', '978'],
#  'HEINWORK': ['979', '980'],
#  'PEINWORK': ['981', '982'],
#  'HEINSCHL': ['983', '984'],
#  'PEINSCHL': ['985', '986'],
#  'HEINCAFE': ['987', '988'],
#  'PEINCAFE': ['989', '990'],
#  'HEINTRAV': ['991', '992'],
#  'PEINTRAV': ['993', '994'],
#  'HEINLICO': ['995', '996'],
#  'PEINLICO': ['997', '998'],
#  'HEINELHO': ['999', '1000'],
#  'PEINELHO': ['1001', '1002'],
#  'HEINOTHR': ['1003', '1004'],
#  'PEINOTHR': ['1005', '1006'],
#  'HENETCHK': ['1007', '1008'],
#  'HEHOMSU1': ['1009', '1010'],
#  'HEHOMSU2': ['1011', '1012'],
#  'HEHOMSU3': ['1013', '1014'],
#  'HEHOMSU4': ['1015', '1016'],
#  'HEHOMSU5': ['1017', '1018'],
#  'HEHOMFAC': ['1019', '1020'],
#  'HEHOMTE1': ['1021', '1022'],
#  'HEHOMTE2': ['1023', '1024'],
#  'HEHOMTE3': ['1025', '1026'],
#  'HEHOMTE4': ['1027', '1028'],
#  'HEHOMTE5': ['1029', '1030'],
#  'HEBUNDLE': ['1031', '1032'],
#  'HEBUNSV1': ['1033', '1034'],
#  'HEBUNSV2': ['1035', '1036'],
#  'HEBUNSV3': ['1037', '1038'],
#  'HEBUNSV4': ['1039', '1040'],
#  'HEBUNSV5': ['1041', '1042'],
#  'HEOUTMOB': ['1043', '1044'],
#  'HEOUTCK': ['1045', '1046'],
#  'PEEMAIL': ['1047', '1048'],
#  'PETEXTIM': ['1049', '1050'],
#  'PESOCIAL': ['1051', '1052'],
#  'PECONFER': ['1053', '1054'],
#  'PEWEBBRO': ['1055', '1056'],
#  'PEVIDEO': ['1057', '1058'],
#  'PEAUDIO': ['1059', '1060'],
#  'PEONTHEG': ['1061', '1062'],
#  'PETELEWK': ['1063', '1064'],
#  'PEJOBSCH': ['1065', '1066'],
#  'PEEDTRAI': ['1067', '1068'],
#  'PEFINANC': ['1069', '1070'],
#  'PEECOMME': ['1071', '1072'],
#  'PEHOMIOT': ['1073', '1074'],
#  'PEMEDINF': ['1075', '1076'],
#  'PEMEDCOM': ['1077', '1078'],
#  'PEMEDMON': ['1079', '1080'],
#  'HEPSPRE1': ['1081', '1082'],
#  'HEPSPRE2': ['1083', '1084'],
#  'HEPSPRE3': ['1085', '1086'],
#  'HEPSPRE4': ['1087', '1088'],
#  'HEPSCON1': ['1089', '1090'],
#  'HEPSCON2': ['1091', '1092'],
#  'HEPSCON3': ['1093', '1094'],
#  'HEPSCON4': ['1095', '1096'],
#  'HEPSCON5': ['1097', '1098'],
#  'HEPSCON6': ['1099', '1100'],
#  'HEPSCON7': ['1101', '1102'],
#  'HEPSCON8': ['1103', '1104'],
#  'HECYBA': ['1105', '1106'],
#  'HECBULLY': ['1107', '1108'],
#  'HEEVRHOM': ['1109', '1110'],
#  'HENOHM1': ['1111', '1112'],
#  'HENOHM2': ['1113', '1114'],
#  'HENOHM3': ['1115', '1116'],
#  'HENOHM4': ['1117', '1118'],
#  'HENOHM5': ['1119', '1120'],
#  'HENOHM6': ['1121', '1122'],
#  'HENOHM7': ['1123', '1124'],
#  'HENOHM8': ['1125', '1126'],
#  'HENOHM9': ['1127', '1128'],
#  'HENOHM10': ['1129', '1130'],
#  'HENOHM11': ['1131', '1132'],
#  'HEPRINOH': ['1133', '1134'],
#  'HEPSENSI': ['1135', '1136'],
#  'HEEVROUT': ['1137', '1138'],
#  'HENOOU1': ['1139', '1140'],
#  'HENOOU2': ['1141', '1142'],
#  'HENOOU3': ['1143', '1144'],
#  'HENOOU4': ['1145', '1146'],
#  'HENOOU5': ['1147', '1148'],
#  'HENOOU6': ['1149', '1150'],
#  'HENOOU7': ['1151', '1152'],
#  'HENOOU8': ['1153', '1154'],
#  'HENOOU9': ['1155', '1156'],
#  'HENOOU10': ['1157', '1158'],
#  'HENOOU11': ['1159', '1160'],
#  'HEPRINOO': ['1161', '1162'],
#  'PUELGFLG': ['1163', '1164'],
#  'PWPRMWGT': ['1165', '1174']}
